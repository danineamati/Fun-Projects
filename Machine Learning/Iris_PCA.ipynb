# %% [markdown]
# # Now we want to look at PCA on the Irix Flower Dataset
# ### First see the SVM File
#
# #### Daniel Neamati (5 July 2019)

# %%
# Import statements

# Machine Learning
from sklearn import datasets
from sklearn.decomposition import PCA

# Plotting
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()

X = iris.data
y = iris.target
target_names = iris.target_names

pca = PCA(n_components=2)
X_r = pca.fit(X).transform(X)

# Percentage of variance explained for each components
print('explained variance ratio (first two components): %s'
      % str(pca.explained_variance_ratio_))
# Out:
# explained variance ratio (first two components): [0.92461872 0.05306648]

# %% [markdown]
# ## Now we want to visualize the result

# %%
for i, target_name in zip([0, 1, 2], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], alpha=.8,
                label=target_name)

plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('PCA of IRIS dataset')
plt.xlabel('First Component')
plt.ylabel('Second Component')
plt.show()
